# %%
# %matplotlib inline
import argparse
import codecs
import collections
import random
import re
import time
import matplotlib.pyplot as plt
import numpy as np

import chainer
from chainer import cuda
import chainer.functions as F
import chainer.links as L
from chainer import optimizers, serializers

plt.style.use('ggplot')

# %%
#学習数
n_epoch = 400  
# 中間層の数
n_units   = 30
#バッチサイズ
batchsize = 25      # minibatch size
#ラベル(肯定、否定、、、)の数
n_label = 5 
# number of epochs per evaluation
epoch_per_eval = 5

# %%
class SexpParser(object):

    def __init__(self, line):
        self.tokens = re.findall(r'\(|\)|[^\(\) ]+', line)
        self.pos = 0

    def parse(self):
        assert self.pos < len(self.tokens)
        token = self.tokens[self.pos]
        assert token != ')'
        self.pos += 1

        if token == '(':
            children = []
            while True:
                assert self.pos < len(self.tokens)
                if self.tokens[self.pos] == ')':
                    self.pos += 1
                    break
                else:
                    children.append(self.parse())
            return children
        else:
            return token

# %%
def convert_tree(vocab, exp):
    assert isinstance(exp, list) and (len(exp) == 2 or len(exp) == 3)

    if len(exp) == 2:
        label, leaf = exp
        if leaf not in vocab:
            vocab[leaf] = len(vocab)
        return {'label': int(label), 'node': vocab[leaf]}
    elif len(exp) == 3:
        label, left, right = exp
        node = (convert_tree(vocab, left), convert_tree(vocab, right))
        return {'label': int(label), 'node': node}

# %%
def read_corpus(path, vocab, max_size):
    with codecs.open(path, encoding='utf-8') as f:
        trees = []
        for line in f:
            line = line.strip()
            tree = SexpParser(line).parse()
            trees.append(convert_tree(vocab, tree))
            if max_size and len(trees) >= max_size:
                break

        return trees

# %%
class RecursiveNet(chainer.Chain):

    def __init__(self, n_vocab, n_units):
        super(RecursiveNet, self).__init__(
            embed=L.EmbedID(n_vocab, n_units),
            l=L.Linear(n_units * 2, n_units),
            w=L.Linear(n_units, n_label))

    def leaf(self, x):
        return self.embed(x)

    def node(self, left, right):
        return F.tanh(self.l(F.concat((left, right))))

    def label(self, v):
        return self.w(v)

# %%
def traverse(model, node, train=True, evaluate=None, root=True):
    if isinstance(node['node'], int):
        # leaf node
        word = np.array([node['node']], np.int32)
        loss = 0
        x = chainer.Variable(word, volatile=not train)
        v = model.leaf(x)
    else:
        # internal node
        left_node, right_node = node['node']
        left_loss, left = traverse(
            model, left_node, train=train, evaluate=evaluate, root=False)
        right_loss, right = traverse(
            model, right_node, train=train, evaluate=evaluate, root=False)
        v = model.node(left, right)
        loss = left_loss + right_loss

    y = model.label(v)

    if train:
        label = np.array([node['label']], np.int32)
        t = chainer.Variable(label, volatile=not train)
        loss += F.softmax_cross_entropy(y, t)

    if evaluate is not None:
        predict = cuda.to_cpu(y.data.argmax(1))
        if predict[0] == node['label']:
            evaluate['correct_node'] += 1
        evaluate['total_node'] += 1

        if root:
            if predict[0] == node['label']:
                evaluate['correct_root'] += 1
            evaluate['total_root'] += 1

    return loss, v

# %%
def evaluate(model, test_trees):
    m = model.copy()
    m.volatile = True
    result = collections.defaultdict(lambda: 0)
    for tree in test_trees:
        traverse(m, tree, train=False, evaluate=result)

    acc_node = 100.0 * result['correct_node'] / result['total_node']
    acc_root = 100.0 * result['correct_root'] / result['total_root']
    print(' Node accuracy: {0:.2f} %% ({1:,d}/{2:,d})'.format(
        acc_node, result['correct_node'], result['total_node']))
    print(' Root accuracy: {0:.2f} %% ({1:,d}/{2:,d})'.format(
        acc_root, result['correct_root'], result['total_root']))

# %%
vocab = {}
max_size=10
train_trees = read_corpus('trees/train.txt', vocab, max_size)
test_trees = read_corpus('trees/test.txt', vocab, max_size)
develop_trees = read_corpus('trees/dev.txt', vocab, max_size)

# %%
#Setup model
model = RecursiveNet(len(vocab), n_units)

# %%
# Setup optimizer
optimizer = optimizers.AdaGrad(lr=0.1)
optimizer.setup(model)
optimizer.add_hook(chainer.optimizer.WeightDecay(0.0001))

# %%
accum_loss = 0
count = 0
start_at = time.time()
cur_at = start_at

# %%
for epoch in range(n_epoch):
    print('Epoch: {0:d}'.format(epoch))
    total_loss = 0
    cur_at = time.time()
    random.shuffle(train_trees)
    for tree in train_trees:
        loss, v = traverse(model, tree, train=True)
        accum_loss += loss
        count += 1

        if count >= batchsize:
            model.zerograds()
            accum_loss.backward()
            optimizer.update()
            total_loss += float(accum_loss.data)

            accum_loss = 0
            count = 0

    print('loss: {:.2f}'.format(total_loss))

    now = time.time()
    throuput = float(len(train_trees)) / (now - cur_at)
    print('{:.2f} iters/sec, {:.2f} sec'.format(throuput, now - cur_at))
    print()

    if (epoch + 1) % epoch_per_eval == 0:
        print('Train data evaluation:')
        evaluate(model, train_trees)
        print('Develop data evaluation:')
        evaluate(model, develop_trees)
        print('')
# Out:
# Epoch: 0
# loss: 0.00
# 19.36 iters/sec, 0.52 sec
#
# Epoch: 1
# loss: 0.00
# 20.23 iters/sec, 0.49 sec
#
# Epoch: 2
# loss: 2054.80
# 12.83 iters/sec, 0.78 sec
#
# Epoch: 3
# loss: 0.00
# 20.59 iters/sec, 0.49 sec
#
# Epoch: 4
# loss: 1286.08
# 12.21 iters/sec, 0.82 sec
#
# Train data evaluation:
#  Node accuracy: 68.47 %% (304/444)
#  Root accuracy: 20.00 %% (2/10)
# Develop data evaluation:
#  Node accuracy: 47.54 %% (174/366)
#  Root accuracy: 20.00 %% (2/10)
#
# Epoch: 5
# loss: 0.00
# 20.98 iters/sec, 0.48 sec
#
# Epoch: 6
# loss: 0.00
# 21.37 iters/sec, 0.47 sec
#
# Epoch: 7
# loss: 1102.45
# 13.01 iters/sec, 0.77 sec
#
# Epoch: 8
# loss: 0.00
# 12.97 iters/sec, 0.77 sec
#
# Epoch: 9
# loss: 1286.13
# 8.29 iters/sec, 1.21 sec
#
# Train data evaluation:
#  Node accuracy: 80.18 %% (356/444)
#  Root accuracy: 40.00 %% (4/10)
# Develop data evaluation:
#  Node accuracy: 47.81 %% (175/366)
#  Root accuracy: 10.00 %% (1/10)
#
# Epoch: 10
# loss: 0.00
# 20.70 iters/sec, 0.48 sec
#
# Epoch: 11
# loss: 0.00
# 8.94 iters/sec, 1.12 sec
#
# Epoch: 12
# loss: 776.58
# 11.91 iters/sec, 0.84 sec
#
# Epoch: 13
# loss: 0.00
# 21.40 iters/sec, 0.47 sec
#
# Epoch: 14
# loss: 640.67
# 11.91 iters/sec, 0.84 sec
#
# Train data evaluation:
#  Node accuracy: 90.54 %% (402/444)
#  Root accuracy: 90.00 %% (9/10)
# Develop data evaluation:
#  Node accuracy: 52.19 %% (191/366)
#  Root accuracy: 30.00 %% (3/10)
#
# Epoch: 15
# loss: 0.00
# 18.43 iters/sec, 0.54 sec
#
# Epoch: 16
# loss: 0.00
# 19.90 iters/sec, 0.50 sec
#
# Epoch: 17
# loss: 477.73
# 12.67 iters/sec, 0.79 sec
#
# Epoch: 18
# loss: 0.00
# 19.52 iters/sec, 0.51 sec
#
# Epoch: 19
# loss: 355.10
# 12.15 iters/sec, 0.82 sec
#
# Train data evaluation:
#  Node accuracy: 93.47 %% (415/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 51.64 %% (189/366)
#  Root accuracy: 10.00 %% (1/10)
#
# Epoch: 20
# loss: 0.00
# 14.90 iters/sec, 0.67 sec
#
# Epoch: 21
# loss: 0.00
# 13.34 iters/sec, 0.75 sec
#
# Epoch: 22
# loss: 286.89
# 10.20 iters/sec, 0.98 sec
#
# Epoch: 23
# loss: 0.00
# 14.95 iters/sec, 0.67 sec
#
# Epoch: 24
# loss: 250.66
# 8.23 iters/sec, 1.22 sec
#
# Train data evaluation:
#  Node accuracy: 97.52 %% (433/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 52.19 %% (191/366)
#  Root accuracy: 10.00 %% (1/10)
#
# Epoch: 25
# loss: 0.00
# 10.96 iters/sec, 0.91 sec
#
# Epoch: 26
# loss: 0.00
# 19.54 iters/sec, 0.51 sec
#
# Epoch: 27
# loss: 188.03
# 8.29 iters/sec, 1.21 sec
#
# Epoch: 28
# loss: 0.00
# 19.29 iters/sec, 0.52 sec
#
# Epoch: 29
# loss: 158.51
# 12.88 iters/sec, 0.78 sec
#
# Train data evaluation:
#  Node accuracy: 99.10 %% (440/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 52.46 %% (192/366)
#  Root accuracy: 20.00 %% (2/10)
#
# Epoch: 30
# loss: 0.00
# 10.25 iters/sec, 0.98 sec
#
# Epoch: 31
# loss: 0.00
# 18.98 iters/sec, 0.53 sec
#
# Epoch: 32
# loss: 124.89
# 7.63 iters/sec, 1.31 sec
#
# Epoch: 33
# loss: 0.00
# 15.89 iters/sec, 0.63 sec
#
# Epoch: 34
# loss: 110.39
# 12.59 iters/sec, 0.79 sec
#
# Train data evaluation:
#  Node accuracy: 99.77 %% (443/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.28 %% (195/366)
#  Root accuracy: 30.00 %% (3/10)
#
# Epoch: 35
# loss: 0.00
# 19.64 iters/sec, 0.51 sec
#
# Epoch: 36
# loss: 0.00
# 22.11 iters/sec, 0.45 sec
#
# Epoch: 37
# loss: 88.19
# 12.54 iters/sec, 0.80 sec
#
# Epoch: 38
# loss: 0.00
# 18.81 iters/sec, 0.53 sec
#
# Epoch: 39
# loss: 81.56
# 8.50 iters/sec, 1.18 sec
#
# Train data evaluation:
#  Node accuracy: 99.77 %% (443/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.28 %% (195/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 40
# loss: 0.00
# 22.01 iters/sec, 0.45 sec
#
# Epoch: 41
# loss: 0.00
# 21.99 iters/sec, 0.45 sec
#
# Epoch: 42
# loss: 70.63
# 12.90 iters/sec, 0.77 sec
#
# Epoch: 43
# loss: 0.00
# 22.54 iters/sec, 0.44 sec
#
# Epoch: 44
# loss: 57.25
# 14.41 iters/sec, 0.69 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.01 %% (194/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 45
# loss: 0.00
# 12.30 iters/sec, 0.81 sec
#
# Epoch: 46
# loss: 0.00
# 15.51 iters/sec, 0.64 sec
#
# Epoch: 47
# loss: 52.98
# 13.07 iters/sec, 0.76 sec
#
# Epoch: 48
# loss: 0.00
# 20.76 iters/sec, 0.48 sec
#
# Epoch: 49
# loss: 47.11
# 12.32 iters/sec, 0.81 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 52.46 %% (192/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 50
# loss: 0.00
# 20.99 iters/sec, 0.48 sec
#
# Epoch: 51
# loss: 0.00
# 20.20 iters/sec, 0.49 sec
#
# Epoch: 52
# loss: 41.09
# 8.27 iters/sec, 1.21 sec
#
# Epoch: 53
# loss: 0.00
# 17.64 iters/sec, 0.57 sec
#
# Epoch: 54
# loss: 39.93
# 12.00 iters/sec, 0.83 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.83 %% (197/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 55
# loss: 0.00
# 19.87 iters/sec, 0.50 sec
#
# Epoch: 56
# loss: 0.00
# 20.65 iters/sec, 0.48 sec
#
# Epoch: 57
# loss: 36.37
# 7.60 iters/sec, 1.32 sec
#
# Epoch: 58
# loss: 0.00
# 9.07 iters/sec, 1.10 sec
#
# Epoch: 59
# loss: 30.92
# 7.51 iters/sec, 1.33 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.28 %% (195/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 60
# loss: 0.00
# 20.21 iters/sec, 0.49 sec
#
# Epoch: 61
# loss: 0.00
# 21.58 iters/sec, 0.46 sec
#
# Epoch: 62
# loss: 29.31
# 14.47 iters/sec, 0.69 sec
#
# Epoch: 63
# loss: 0.00
# 22.70 iters/sec, 0.44 sec
#
# Epoch: 64
# loss: 27.74
# 10.85 iters/sec, 0.92 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.83 %% (197/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 65
# loss: 0.00
# 19.87 iters/sec, 0.50 sec
#
# Epoch: 66
# loss: 0.00
# 22.12 iters/sec, 0.45 sec
#
# Epoch: 67
# loss: 26.53
# 10.69 iters/sec, 0.94 sec
#
# Epoch: 68
# loss: 0.00
# 21.35 iters/sec, 0.47 sec
#
# Epoch: 69
# loss: 22.68
# 13.99 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.28 %% (195/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 70
# loss: 0.00
# 19.73 iters/sec, 0.51 sec
#
# Epoch: 71
# loss: 0.00
# 20.12 iters/sec, 0.50 sec
#
# Epoch: 72
# loss: 22.58
# 10.36 iters/sec, 0.96 sec
#
# Epoch: 73
# loss: 0.00
# 20.27 iters/sec, 0.49 sec
#
# Epoch: 74
# loss: 20.45
# 14.50 iters/sec, 0.69 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.28 %% (195/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 75
# loss: 0.00
# 23.87 iters/sec, 0.42 sec
#
# Epoch: 76
# loss: 0.00
# 21.34 iters/sec, 0.47 sec
#
# Epoch: 77
# loss: 18.79
# 8.83 iters/sec, 1.13 sec
#
# Epoch: 78
# loss: 0.00
# 18.90 iters/sec, 0.53 sec
#
# Epoch: 79
# loss: 19.27
# 9.30 iters/sec, 1.08 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.01 %% (194/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 80
# loss: 0.00
# 20.97 iters/sec, 0.48 sec
#
# Epoch: 81
# loss: 0.00
# 22.52 iters/sec, 0.44 sec
#
# Epoch: 82
# loss: 17.16
# 14.24 iters/sec, 0.70 sec
#
# Epoch: 83
# loss: 0.00
# 15.49 iters/sec, 0.65 sec
#
# Epoch: 84
# loss: 16.84
# 12.59 iters/sec, 0.79 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.55 %% (196/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 85
# loss: 0.00
# 12.57 iters/sec, 0.80 sec
#
# Epoch: 86
# loss: 0.00
# 14.77 iters/sec, 0.68 sec
#
# Epoch: 87
# loss: 16.62
# 11.60 iters/sec, 0.86 sec
#
# Epoch: 88
# loss: 0.00
# 17.74 iters/sec, 0.56 sec
#
# Epoch: 89
# loss: 14.00
# 10.35 iters/sec, 0.97 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.83 %% (197/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 90
# loss: 0.00
# 9.67 iters/sec, 1.03 sec
#
# Epoch: 91
# loss: 0.00
# 9.05 iters/sec, 1.11 sec
#
# Epoch: 92
# loss: 14.40
# 5.56 iters/sec, 1.80 sec
#
# Epoch: 93
# loss: 0.00
# 10.20 iters/sec, 0.98 sec
#
# Epoch: 94
# loss: 13.39
# 2.94 iters/sec, 3.41 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 53.55 %% (196/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 95
# loss: 0.00
# 18.13 iters/sec, 0.55 sec
#
# Epoch: 96
# loss: 0.00
# 21.30 iters/sec, 0.47 sec
#
# Epoch: 97
# loss: 12.66
# 12.04 iters/sec, 0.83 sec
#
# Epoch: 98
# loss: 0.00
# 15.38 iters/sec, 0.65 sec
#
# Epoch: 99
# loss: 12.75
# 11.13 iters/sec, 0.90 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 54.92 %% (201/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 100
# loss: 0.00
# 16.91 iters/sec, 0.59 sec
#
# Epoch: 101
# loss: 0.00
# 20.99 iters/sec, 0.48 sec
#
# Epoch: 102
# loss: 11.66
# 6.85 iters/sec, 1.46 sec
#
# Epoch: 103
# loss: 0.00
# 18.76 iters/sec, 0.53 sec
#
# Epoch: 104
# loss: 11.71
# 12.17 iters/sec, 0.82 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 54.92 %% (201/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 105
# loss: 0.00
# 21.07 iters/sec, 0.47 sec
#
# Epoch: 106
# loss: 0.00
# 19.64 iters/sec, 0.51 sec
#
# Epoch: 107
# loss: 10.27
# 13.21 iters/sec, 0.76 sec
#
# Epoch: 108
# loss: 0.00
# 18.45 iters/sec, 0.54 sec
#
# Epoch: 109
# loss: 11.34
# 11.53 iters/sec, 0.87 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.19 %% (202/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 110
# loss: 0.00
# 11.59 iters/sec, 0.86 sec
#
# Epoch: 111
# loss: 0.00
# 15.59 iters/sec, 0.64 sec
#
# Epoch: 112
# loss: 10.68
# 12.27 iters/sec, 0.81 sec
#
# Epoch: 113
# loss: 0.00
# 19.86 iters/sec, 0.50 sec
#
# Epoch: 114
# loss: 9.40
# 12.90 iters/sec, 0.78 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.19 %% (202/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 115
# loss: 0.00
# 21.97 iters/sec, 0.46 sec
#
# Epoch: 116
# loss: 0.00
# 18.74 iters/sec, 0.53 sec
#
# Epoch: 117
# loss: 9.03
# 8.56 iters/sec, 1.17 sec
#
# Epoch: 118
# loss: 0.00
# 10.60 iters/sec, 0.94 sec
#
# Epoch: 119
# loss: 9.71
# 7.21 iters/sec, 1.39 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.19 %% (202/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 120
# loss: 0.00
# 17.58 iters/sec, 0.57 sec
#
# Epoch: 121
# loss: 0.00
# 16.70 iters/sec, 0.60 sec
#
# Epoch: 122
# loss: 9.47
# 10.52 iters/sec, 0.95 sec
#
# Epoch: 123
# loss: 0.00
# 15.08 iters/sec, 0.66 sec
#
# Epoch: 124
# loss: 8.08
# 11.87 iters/sec, 0.84 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.19 %% (202/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 125
# loss: 0.00
# 21.88 iters/sec, 0.46 sec
#
# Epoch: 126
# loss: 0.00
# 23.20 iters/sec, 0.43 sec
#
# Epoch: 127
# loss: 8.33
# 13.40 iters/sec, 0.75 sec
#
# Epoch: 128
# loss: 0.00
# 20.92 iters/sec, 0.48 sec
#
# Epoch: 129
# loss: 8.16
# 13.98 iters/sec, 0.72 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.19 %% (202/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 130
# loss: 0.00
# 22.40 iters/sec, 0.45 sec
#
# Epoch: 131
# loss: 0.00
# 23.16 iters/sec, 0.43 sec
#
# Epoch: 132
# loss: 8.07
# 12.50 iters/sec, 0.80 sec
#
# Epoch: 133
# loss: 0.00
# 21.17 iters/sec, 0.47 sec
#
# Epoch: 134
# loss: 7.47
# 14.14 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.74 %% (204/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 135
# loss: 0.00
# 22.54 iters/sec, 0.44 sec
#
# Epoch: 136
# loss: 0.00
# 18.87 iters/sec, 0.53 sec
#
# Epoch: 137
# loss: 7.94
# 12.58 iters/sec, 0.79 sec
#
# Epoch: 138
# loss: 0.00
# 19.44 iters/sec, 0.51 sec
#
# Epoch: 139
# loss: 6.75
# 12.23 iters/sec, 0.82 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.74 %% (204/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 140
# loss: 0.00
# 22.32 iters/sec, 0.45 sec
#
# Epoch: 141
# loss: 0.00
# 21.64 iters/sec, 0.46 sec
#
# Epoch: 142
# loss: 7.14
# 13.18 iters/sec, 0.76 sec
#
# Epoch: 143
# loss: 0.00
# 20.77 iters/sec, 0.48 sec
#
# Epoch: 144
# loss: 6.78
# 14.07 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.74 %% (204/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 145
# loss: 0.00
# 21.44 iters/sec, 0.47 sec
#
# Epoch: 146
# loss: 0.00
# 21.83 iters/sec, 0.46 sec
#
# Epoch: 147
# loss: 6.93
# 12.45 iters/sec, 0.80 sec
#
# Epoch: 148
# loss: 0.00
# 22.52 iters/sec, 0.44 sec
#
# Epoch: 149
# loss: 6.29
# 13.16 iters/sec, 0.76 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 150
# loss: 0.00
# 21.67 iters/sec, 0.46 sec
#
# Epoch: 151
# loss: 0.00
# 20.32 iters/sec, 0.49 sec
#
# Epoch: 152
# loss: 6.55
# 12.94 iters/sec, 0.77 sec
#
# Epoch: 153
# loss: 0.00
# 20.76 iters/sec, 0.48 sec
#
# Epoch: 154
# loss: 6.03
# 12.16 iters/sec, 0.82 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 155
# loss: 0.00
# 23.00 iters/sec, 0.43 sec
#
# Epoch: 156
# loss: 0.00
# 21.89 iters/sec, 0.46 sec
#
# Epoch: 157
# loss: 6.10
# 14.18 iters/sec, 0.71 sec
#
# Epoch: 158
# loss: 0.00
# 21.00 iters/sec, 0.48 sec
#
# Epoch: 159
# loss: 5.90
# 14.64 iters/sec, 0.68 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 160
# loss: 0.00
# 23.28 iters/sec, 0.43 sec
#
# Epoch: 161
# loss: 0.00
# 23.51 iters/sec, 0.43 sec
#
# Epoch: 162
# loss: 5.59
# 13.31 iters/sec, 0.75 sec
#
# Epoch: 163
# loss: 0.00
# 22.58 iters/sec, 0.44 sec
#
# Epoch: 164
# loss: 5.88
# 11.60 iters/sec, 0.86 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 165
# loss: 0.00
# 23.25 iters/sec, 0.43 sec
#
# Epoch: 166
# loss: 0.00
# 21.36 iters/sec, 0.47 sec
#
# Epoch: 167
# loss: 5.63
# 14.15 iters/sec, 0.71 sec
#
# Epoch: 168
# loss: 0.00
# 23.26 iters/sec, 0.43 sec
#
# Epoch: 169
# loss: 5.35
# 12.50 iters/sec, 0.80 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 170
# loss: 0.00
# 20.91 iters/sec, 0.48 sec
#
# Epoch: 171
# loss: 0.00
# 21.47 iters/sec, 0.47 sec
#
# Epoch: 172
# loss: 5.43
# 13.05 iters/sec, 0.77 sec
#
# Epoch: 173
# loss: 0.00
# 19.11 iters/sec, 0.52 sec
#
# Epoch: 174
# loss: 5.10
# 13.21 iters/sec, 0.76 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.74 %% (204/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 175
# loss: 0.00
# 22.45 iters/sec, 0.45 sec
#
# Epoch: 176
# loss: 0.00
# 22.19 iters/sec, 0.45 sec
#
# Epoch: 177
# loss: 5.07
# 12.83 iters/sec, 0.78 sec
#
# Epoch: 178
# loss: 0.00
# 20.80 iters/sec, 0.48 sec
#
# Epoch: 179
# loss: 5.04
# 12.96 iters/sec, 0.77 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.74 %% (204/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 180
# loss: 0.00
# 21.85 iters/sec, 0.46 sec
#
# Epoch: 181
# loss: 0.00
# 19.72 iters/sec, 0.51 sec
#
# Epoch: 182
# loss: 4.98
# 12.81 iters/sec, 0.78 sec
#
# Epoch: 183
# loss: 0.00
# 22.18 iters/sec, 0.45 sec
#
# Epoch: 184
# loss: 4.74
# 12.42 iters/sec, 0.81 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 55.74 %% (204/366)
#  Root accuracy: 40.00 %% (4/10)
#
# Epoch: 185
# loss: 0.00
# 21.85 iters/sec, 0.46 sec
#
# Epoch: 186
# loss: 0.00
# 20.76 iters/sec, 0.48 sec
#
# Epoch: 187
# loss: 4.70
# 13.69 iters/sec, 0.73 sec
#
# Epoch: 188
# loss: 0.00
# 20.51 iters/sec, 0.49 sec
#
# Epoch: 189
# loss: 4.65
# 13.28 iters/sec, 0.75 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 190
# loss: 0.00
# 16.54 iters/sec, 0.60 sec
#
# Epoch: 191
# loss: 0.00
# 8.70 iters/sec, 1.15 sec
#
# Epoch: 192
# loss: 4.37
# 10.48 iters/sec, 0.95 sec
#
# Epoch: 193
# loss: 0.00
# 19.97 iters/sec, 0.50 sec
#
# Epoch: 194
# loss: 4.65
# 12.75 iters/sec, 0.78 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.01 %% (205/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 195
# loss: 0.00
# 23.30 iters/sec, 0.43 sec
#
# Epoch: 196
# loss: 0.00
# 18.79 iters/sec, 0.53 sec
#
# Epoch: 197
# loss: 4.22
# 13.28 iters/sec, 0.75 sec
#
# Epoch: 198
# loss: 0.00
# 21.34 iters/sec, 0.47 sec
#
# Epoch: 199
# loss: 4.48
# 12.01 iters/sec, 0.83 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.28 %% (206/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 200
# loss: 0.00
# 16.32 iters/sec, 0.61 sec
#
# Epoch: 201
# loss: 0.00
# 15.92 iters/sec, 0.63 sec
#
# Epoch: 202
# loss: 4.33
# 8.51 iters/sec, 1.18 sec
#
# Epoch: 203
# loss: 0.00
# 15.16 iters/sec, 0.66 sec
#
# Epoch: 204
# loss: 4.07
# 9.27 iters/sec, 1.08 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.83 %% (208/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 205
# loss: 0.00
# 22.56 iters/sec, 0.44 sec
#
# Epoch: 206
# loss: 0.00
# 23.48 iters/sec, 0.43 sec
#
# Epoch: 207
# loss: 4.10
# 11.52 iters/sec, 0.87 sec
#
# Epoch: 208
# loss: 0.00
# 22.52 iters/sec, 0.44 sec
#
# Epoch: 209
# loss: 4.02
# 14.11 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.56 %% (207/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 210
# loss: 0.00
# 22.94 iters/sec, 0.44 sec
#
# Epoch: 211
# loss: 0.00
# 10.36 iters/sec, 0.96 sec
#
# Epoch: 212
# loss: 3.99
# 10.61 iters/sec, 0.94 sec
#
# Epoch: 213
# loss: 0.00
# 15.33 iters/sec, 0.65 sec
#
# Epoch: 214
# loss: 3.88
# 11.93 iters/sec, 0.84 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.56 %% (207/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 215
# loss: 0.00
# 21.90 iters/sec, 0.46 sec
#
# Epoch: 216
# loss: 0.00
# 22.42 iters/sec, 0.45 sec
#
# Epoch: 217
# loss: 3.88
# 12.88 iters/sec, 0.78 sec
#
# Epoch: 218
# loss: 0.00
# 19.08 iters/sec, 0.52 sec
#
# Epoch: 219
# loss: 3.74
# 13.05 iters/sec, 0.77 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 56.83 %% (208/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 220
# loss: 0.00
# 23.27 iters/sec, 0.43 sec
#
# Epoch: 221
# loss: 0.00
# 21.43 iters/sec, 0.47 sec
#
# Epoch: 222
# loss: 3.62
# 10.89 iters/sec, 0.92 sec
#
# Epoch: 223
# loss: 0.00
# 20.77 iters/sec, 0.48 sec
#
# Epoch: 224
# loss: 3.77
# 10.44 iters/sec, 0.96 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.38 %% (210/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 225
# loss: 0.00
# 8.07 iters/sec, 1.24 sec
#
# Epoch: 226
# loss: 0.00
# 16.24 iters/sec, 0.62 sec
#
# Epoch: 227
# loss: 3.45
# 9.48 iters/sec, 1.05 sec
#
# Epoch: 228
# loss: 0.00
# 18.53 iters/sec, 0.54 sec
#
# Epoch: 229
# loss: 3.72
# 7.30 iters/sec, 1.37 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.10 %% (209/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 230
# loss: 0.00
# 16.75 iters/sec, 0.60 sec
#
# Epoch: 231
# loss: 0.00
# 23.51 iters/sec, 0.43 sec
#
# Epoch: 232
# loss: 3.54
# 11.60 iters/sec, 0.86 sec
#
# Epoch: 233
# loss: 0.00
# 10.42 iters/sec, 0.96 sec
#
# Epoch: 234
# loss: 3.42
# 8.40 iters/sec, 1.19 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.10 %% (209/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 235
# loss: 0.00
# 18.70 iters/sec, 0.53 sec
#
# Epoch: 236
# loss: 0.00
# 15.42 iters/sec, 0.65 sec
#
# Epoch: 237
# loss: 3.48
# 12.76 iters/sec, 0.78 sec
#
# Epoch: 238
# loss: 0.00
# 21.16 iters/sec, 0.47 sec
#
# Epoch: 239
# loss: 3.29
# 13.18 iters/sec, 0.76 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.38 %% (210/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 240
# loss: 0.00
# 22.60 iters/sec, 0.44 sec
#
# Epoch: 241
# loss: 0.00
# 18.20 iters/sec, 0.55 sec
#
# Epoch: 242
# loss: 3.41
# 12.49 iters/sec, 0.80 sec
#
# Epoch: 243
# loss: 0.00
# 22.00 iters/sec, 0.45 sec
#
# Epoch: 244
# loss: 3.17
# 4.96 iters/sec, 2.02 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.65 %% (211/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 245
# loss: 0.00
# 22.58 iters/sec, 0.44 sec
#
# Epoch: 246
# loss: 0.00
# 21.29 iters/sec, 0.47 sec
#
# Epoch: 247
# loss: 3.30
# 14.24 iters/sec, 0.70 sec
#
# Epoch: 248
# loss: 0.00
# 21.37 iters/sec, 0.47 sec
#
# Epoch: 249
# loss: 3.11
# 14.78 iters/sec, 0.68 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.65 %% (211/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 250
# loss: 0.00
# 23.65 iters/sec, 0.42 sec
#
# Epoch: 251
# loss: 0.00
# 23.38 iters/sec, 0.43 sec
#
# Epoch: 252
# loss: 2.92
# 13.63 iters/sec, 0.73 sec
#
# Epoch: 253
# loss: 0.00
# 23.09 iters/sec, 0.43 sec
#
# Epoch: 254
# loss: 3.31
# 14.07 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.92 %% (212/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 255
# loss: 0.00
# 20.80 iters/sec, 0.48 sec
#
# Epoch: 256
# loss: 0.00
# 20.18 iters/sec, 0.50 sec
#
# Epoch: 257
# loss: 3.10
# 13.21 iters/sec, 0.76 sec
#
# Epoch: 258
# loss: 0.00
# 22.69 iters/sec, 0.44 sec
#
# Epoch: 259
# loss: 2.98
# 12.76 iters/sec, 0.78 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 57.92 %% (212/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 260
# loss: 0.00
# 22.54 iters/sec, 0.44 sec
#
# Epoch: 261
# loss: 0.00
# 21.55 iters/sec, 0.46 sec
#
# Epoch: 262
# loss: 2.89
# 12.26 iters/sec, 0.82 sec
#
# Epoch: 263
# loss: 0.00
# 14.74 iters/sec, 0.68 sec
#
# Epoch: 264
# loss: 3.03
# 12.73 iters/sec, 0.79 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 58.20 %% (213/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 265
# loss: 0.00
# 21.94 iters/sec, 0.46 sec
#
# Epoch: 266
# loss: 0.00
# 21.59 iters/sec, 0.46 sec
#
# Epoch: 267
# loss: 2.96
# 13.41 iters/sec, 0.75 sec
#
# Epoch: 268
# loss: 0.00
# 23.30 iters/sec, 0.43 sec
#
# Epoch: 269
# loss: 2.82
# 14.15 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 58.20 %% (213/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 270
# loss: 0.00
# 23.68 iters/sec, 0.42 sec
#
# Epoch: 271
# loss: 0.00
# 21.28 iters/sec, 0.47 sec
#
# Epoch: 272
# loss: 2.95
# 14.22 iters/sec, 0.70 sec
#
# Epoch: 273
# loss: 0.00
# 23.31 iters/sec, 0.43 sec
#
# Epoch: 274
# loss: 2.69
# 13.74 iters/sec, 0.73 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 58.20 %% (213/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 275
# loss: 0.00
# 23.43 iters/sec, 0.43 sec
#
# Epoch: 276
# loss: 0.00
# 23.93 iters/sec, 0.42 sec
#
# Epoch: 277
# loss: 2.66
# 14.71 iters/sec, 0.68 sec
#
# Epoch: 278
# loss: 0.00
# 21.62 iters/sec, 0.46 sec
#
# Epoch: 279
# loss: 2.85
# 12.99 iters/sec, 0.77 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 58.20 %% (213/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 280
# loss: 0.00
# 21.96 iters/sec, 0.46 sec
#
# Epoch: 281
# loss: 0.00
# 22.43 iters/sec, 0.45 sec
#
# Epoch: 282
# loss: 2.75
# 13.26 iters/sec, 0.75 sec
#
# Epoch: 283
# loss: 0.00
# 23.77 iters/sec, 0.42 sec
#
# Epoch: 284
# loss: 2.63
# 13.26 iters/sec, 0.75 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 58.47 %% (214/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 285
# loss: 0.00
# 18.80 iters/sec, 0.53 sec
#
# Epoch: 286
# loss: 0.00
# 13.42 iters/sec, 0.75 sec
#
# Epoch: 287
# loss: 2.89
# 10.44 iters/sec, 0.96 sec
#
# Epoch: 288
# loss: 0.00
# 21.54 iters/sec, 0.46 sec
#
# Epoch: 289
# loss: 2.37
# 12.29 iters/sec, 0.81 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 58.74 %% (215/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 290
# loss: 0.00
# 21.55 iters/sec, 0.46 sec
#
# Epoch: 291
# loss: 0.00
# 22.56 iters/sec, 0.44 sec
#
# Epoch: 292
# loss: 2.49
# 13.21 iters/sec, 0.76 sec
#
# Epoch: 293
# loss: 0.00
# 14.80 iters/sec, 0.68 sec
#
# Epoch: 294
# loss: 2.65
# 13.89 iters/sec, 0.72 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.29 %% (217/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 295
# loss: 0.00
# 20.42 iters/sec, 0.49 sec
#
# Epoch: 296
# loss: 0.00
# 21.86 iters/sec, 0.46 sec
#
# Epoch: 297
# loss: 2.65
# 12.52 iters/sec, 0.80 sec
#
# Epoch: 298
# loss: 0.00
# 22.45 iters/sec, 0.45 sec
#
# Epoch: 299
# loss: 2.38
# 12.65 iters/sec, 0.79 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.29 %% (217/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 300
# loss: 0.00
# 19.08 iters/sec, 0.52 sec
#
# Epoch: 301
# loss: 0.00
# 19.84 iters/sec, 0.50 sec
#
# Epoch: 302
# loss: 2.40
# 13.23 iters/sec, 0.76 sec
#
# Epoch: 303
# loss: 0.00
# 22.43 iters/sec, 0.45 sec
#
# Epoch: 304
# loss: 2.53
# 11.01 iters/sec, 0.91 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.29 %% (217/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 305
# loss: 0.00
# 17.56 iters/sec, 0.57 sec
#
# Epoch: 306
# loss: 0.00
# 18.11 iters/sec, 0.55 sec
#
# Epoch: 307
# loss: 2.52
# 9.44 iters/sec, 1.06 sec
#
# Epoch: 308
# loss: 0.00
# 20.49 iters/sec, 0.49 sec
#
# Epoch: 309
# loss: 2.30
# 13.90 iters/sec, 0.72 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.29 %% (217/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 310
# loss: 0.00
# 18.32 iters/sec, 0.55 sec
#
# Epoch: 311
# loss: 0.00
# 16.14 iters/sec, 0.62 sec
#
# Epoch: 312
# loss: 2.44
# 8.10 iters/sec, 1.23 sec
#
# Epoch: 313
# loss: 0.00
# 17.34 iters/sec, 0.58 sec
#
# Epoch: 314
# loss: 2.29
# 10.07 iters/sec, 0.99 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.02 %% (216/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 315
# loss: 0.00
# 21.63 iters/sec, 0.46 sec
#
# Epoch: 316
# loss: 0.00
# 17.55 iters/sec, 0.57 sec
#
# Epoch: 317
# loss: 2.38
# 12.14 iters/sec, 0.82 sec
#
# Epoch: 318
# loss: 0.00
# 22.04 iters/sec, 0.45 sec
#
# Epoch: 319
# loss: 2.25
# 12.02 iters/sec, 0.83 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.29 %% (217/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 320
# loss: 0.00
# 21.05 iters/sec, 0.48 sec
#
# Epoch: 321
# loss: 0.00
# 22.42 iters/sec, 0.45 sec
#
# Epoch: 322
# loss: 2.30
# 14.12 iters/sec, 0.71 sec
#
# Epoch: 323
# loss: 0.00
# 20.99 iters/sec, 0.48 sec
#
# Epoch: 324
# loss: 2.24
# 14.36 iters/sec, 0.70 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.29 %% (217/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 325
# loss: 0.00
# 23.29 iters/sec, 0.43 sec
#
# Epoch: 326
# loss: 0.00
# 22.79 iters/sec, 0.44 sec
#
# Epoch: 327
# loss: 2.24
# 13.23 iters/sec, 0.76 sec
#
# Epoch: 328
# loss: 0.00
# 20.27 iters/sec, 0.49 sec
#
# Epoch: 329
# loss: 2.20
# 13.65 iters/sec, 0.73 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.56 %% (218/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 330
# loss: 0.00
# 19.15 iters/sec, 0.52 sec
#
# Epoch: 331
# loss: 0.00
# 19.18 iters/sec, 0.52 sec
#
# Epoch: 332
# loss: 2.10
# 14.14 iters/sec, 0.71 sec
#
# Epoch: 333
# loss: 0.00
# 23.14 iters/sec, 0.43 sec
#
# Epoch: 334
# loss: 2.26
# 13.05 iters/sec, 0.77 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.56 %% (218/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 335
# loss: 0.00
# 22.60 iters/sec, 0.44 sec
#
# Epoch: 336
# loss: 0.00
# 22.72 iters/sec, 0.44 sec
#
# Epoch: 337
# loss: 2.17
# 14.25 iters/sec, 0.70 sec
#
# Epoch: 338
# loss: 0.00
# 20.54 iters/sec, 0.49 sec
#
# Epoch: 339
# loss: 2.11
# 13.81 iters/sec, 0.72 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.56 %% (218/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 340
# loss: 0.00
# 22.58 iters/sec, 0.44 sec
#
# Epoch: 341
# loss: 0.00
# 22.39 iters/sec, 0.45 sec
#
# Epoch: 342
# loss: 2.05
# 12.83 iters/sec, 0.78 sec
#
# Epoch: 343
# loss: 0.00
# 20.77 iters/sec, 0.48 sec
#
# Epoch: 344
# loss: 2.15
# 9.03 iters/sec, 1.11 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 59.84 %% (219/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 345
# loss: 0.00
# 21.42 iters/sec, 0.47 sec
#
# Epoch: 346
# loss: 0.00
# 20.09 iters/sec, 0.50 sec
#
# Epoch: 347
# loss: 2.14
# 12.69 iters/sec, 0.79 sec
#
# Epoch: 348
# loss: 0.00
# 23.05 iters/sec, 0.43 sec
#
# Epoch: 349
# loss: 1.98
# 13.49 iters/sec, 0.74 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.38 %% (221/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 350
# loss: 0.00
# 22.35 iters/sec, 0.45 sec
#
# Epoch: 351
# loss: 0.00
# 21.88 iters/sec, 0.46 sec
#
# Epoch: 352
# loss: 1.97
# 13.93 iters/sec, 0.72 sec
#
# Epoch: 353
# loss: 0.00
# 20.02 iters/sec, 0.50 sec
#
# Epoch: 354
# loss: 2.08
# 13.20 iters/sec, 0.76 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.11 %% (220/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 355
# loss: 0.00
# 18.26 iters/sec, 0.55 sec
#
# Epoch: 356
# loss: 0.00
# 16.84 iters/sec, 0.59 sec
#
# Epoch: 357
# loss: 2.03
# 11.04 iters/sec, 0.91 sec
#
# Epoch: 358
# loss: 0.00
# 20.96 iters/sec, 0.48 sec
#
# Epoch: 359
# loss: 1.95
# 12.47 iters/sec, 0.80 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.38 %% (221/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 360
# loss: 0.00
# 22.56 iters/sec, 0.44 sec
#
# Epoch: 361
# loss: 0.00
# 20.66 iters/sec, 0.48 sec
#
# Epoch: 362
# loss: 1.94
# 13.74 iters/sec, 0.73 sec
#
# Epoch: 363
# loss: 0.00
# 17.23 iters/sec, 0.58 sec
#
# Epoch: 364
# loss: 1.98
# 10.71 iters/sec, 0.93 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.38 %% (221/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 365
# loss: 0.00
# 18.68 iters/sec, 0.54 sec
#
# Epoch: 366
# loss: 0.00
# 21.96 iters/sec, 0.46 sec
#
# Epoch: 367
# loss: 1.95
# 13.20 iters/sec, 0.76 sec
#
# Epoch: 368
# loss: 0.00
# 19.78 iters/sec, 0.51 sec
#
# Epoch: 369
# loss: 1.90
# 13.78 iters/sec, 0.73 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.38 %% (221/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 370
# loss: 0.00
# 21.40 iters/sec, 0.47 sec
#
# Epoch: 371
# loss: 0.00
# 22.01 iters/sec, 0.45 sec
#
# Epoch: 372
# loss: 1.95
# 12.70 iters/sec, 0.79 sec
#
# Epoch: 373
# loss: 0.00
# 22.41 iters/sec, 0.45 sec
#
# Epoch: 374
# loss: 1.83
# 14.05 iters/sec, 0.71 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.38 %% (221/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 375
# loss: 0.00
# 19.96 iters/sec, 0.50 sec
#
# Epoch: 376
# loss: 0.00
# 16.37 iters/sec, 0.61 sec
#
# Epoch: 377
# loss: 1.93
# 8.48 iters/sec, 1.18 sec
#
# Epoch: 378
# loss: 0.00
# 15.37 iters/sec, 0.65 sec
#
# Epoch: 379
# loss: 1.78
# 11.81 iters/sec, 0.85 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.66 %% (222/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 380
# loss: 0.00
# 22.83 iters/sec, 0.44 sec
#
# Epoch: 381
# loss: 0.00
# 23.55 iters/sec, 0.42 sec
#
# Epoch: 382
# loss: 1.76
# 14.22 iters/sec, 0.70 sec
#
# Epoch: 383
# loss: 0.00
# 18.27 iters/sec, 0.55 sec
#
# Epoch: 384
# loss: 1.90
# 13.01 iters/sec, 0.77 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.66 %% (222/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 385
# loss: 0.00
# 23.52 iters/sec, 0.43 sec
#
# Epoch: 386
# loss: 0.00
# 21.62 iters/sec, 0.46 sec
#
# Epoch: 387
# loss: 1.84
# 12.45 iters/sec, 0.80 sec
#
# Epoch: 388
# loss: 0.00
# 22.07 iters/sec, 0.45 sec
#
# Epoch: 389
# loss: 1.76
# 13.51 iters/sec, 0.74 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.93 %% (223/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 390
# loss: 0.00
# 22.02 iters/sec, 0.45 sec
#
# Epoch: 391
# loss: 0.00
# 19.98 iters/sec, 0.50 sec
#
# Epoch: 392
# loss: 1.68
# 13.25 iters/sec, 0.75 sec
#
# Epoch: 393
# loss: 0.00
# 20.20 iters/sec, 0.50 sec
#
# Epoch: 394
# loss: 1.86
# 11.70 iters/sec, 0.85 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 61.20 %% (224/366)
#  Root accuracy: 50.00 %% (5/10)
#
# Epoch: 395
# loss: 0.00
# 20.22 iters/sec, 0.49 sec
#
# Epoch: 396
# loss: 0.00
# 21.25 iters/sec, 0.47 sec
#
# Epoch: 397
# loss: 1.83
# 13.10 iters/sec, 0.76 sec
#
# Epoch: 398
# loss: 0.00
# 19.88 iters/sec, 0.50 sec
#
# Epoch: 399
# loss: 1.66
# 13.43 iters/sec, 0.74 sec
#
# Train data evaluation:
#  Node accuracy: 100.00 %% (444/444)
#  Root accuracy: 100.00 %% (10/10)
# Develop data evaluation:
#  Node accuracy: 60.93 %% (223/366)
#  Root accuracy: 50.00 %% (5/10)

# %%
print('Test evaluateion')
evaluate(model, test_trees)
# Out:
# Test evaluateion
#  Node accuracy: 61.86 %% (193/312)
#  Root accuracy: 50.00 %% (5/10)

# %%
# Save the model and the optimizer
print('save the model')
serializers.save_npz('mnist.model', model)
print('save the optimizer')
serializers.save_npz('mnist.state', optimizer)
# Out:
# save the model
# save the optimizer

# %%
# load the model and the optimizer
model = RecursiveNet(len(vocab), n_units)
optimizer = optimizers.AdaGrad(lr=0.1)
optimizer.setup(model)
optimizer.add_hook(chainer.optimizer.WeightDecay(0.0001))
print('load the model')
serializers.load_npz('mnist.model',  model)
print('load the optimizer')
serializers.load_npz('mnist.state', optimizer)
# Out:
# load the model
# load the optimizer

# %%
train_trees [0]
# Out:
# {'label': 2,
#  'node': ({'label': 2,
#    'node': ({'label': 2, 'node': 80},
#     {'label': 2,
#      'node': ({'label': 2, 'node': 81},
#       {'label': 2,
#        'node': ({'label': 2, 'node': 82},
#         {'label': 2,
#          'node': ({'label': 2, 'node': 83}, {'label': 2, 'node': 84})})})})},
#   {'label': 2,
#    'node': ({'label': 2, 'node': 85},
#     {'label': 2,
#      'node': ({'label': 2,
#        'node': ({'label': 2, 'node': 86},
#         {'label': 1,
#          'node': ({'label': 2, 'node': 87},
#           {'label': 2,
#            'node': ({'label': 2,
#              'node': ({'label': 2, 'node': 88},
#               {'label': 1,
#                'node': ({'label': 2, 'node': 89},
#                 {'label': 2,
#                  'node': ({'label': 2, 'node': 37},
#                   {'label': 2,
#                    'node': ({'label': 2, 'node': 90},
#                     {'label': 2,
#                      'node': ({'label': 2, 'node': 91},
#                       {'label': 1, 'node': 92})})})})})},
#             {'label': 4,
#              'node': ({'label': 2, 'node': 93},
#               {'label': 4,
#                'node': ({'label': 3, 'node': 94},
#                 {'label': 3,
#                  'node': ({'label': 2, 'node': 37},
#                   {'label': 3, 'node': 95})})})})})})},
#       {'label': 2, 'node': 33})})})}

# %%
train_trees[0]['node'].
# Out:
# ({'label': 2,
#   'node': ({'label': 2, 'node': 80},
#    {'label': 2,
#     'node': ({'label': 2, 'node': 81},
#      {'label': 2,
#       'node': ({'label': 2, 'node': 82},
#        {'label': 2,
#         'node': ({'label': 2, 'node': 83}, {'label': 2, 'node': 84})})})})},
#  {'label': 2,
#   'node': ({'label': 2, 'node': 85},
#    {'label': 2,
#     'node': ({'label': 2,
#       'node': ({'label': 2, 'node': 86},
#        {'label': 1,
#         'node': ({'label': 2, 'node': 87},
#          {'label': 2,
#           'node': ({'label': 2,
#             'node': ({'label': 2, 'node': 88},
#              {'label': 1,
#               'node': ({'label': 2, 'node': 89},
#                {'label': 2,
#                 'node': ({'label': 2, 'node': 37},
#                  {'label': 2,
#                   'node': ({'label': 2, 'node': 90},
#                    {'label': 2,
#                     'node': ({'label': 2, 'node': 91},
#                      {'label': 1, 'node': 92})})})})})},
#            {'label': 4,
#             'node': ({'label': 2, 'node': 93},
#              {'label': 4,
#               'node': ({'label': 3, 'node': 94},
#                {'label': 3,
#                 'node': ({'label': 2, 'node': 37},
#                  {'label': 3, 'node': 95})})})})})})},
#      {'label': 2, 'node': 33})})})
