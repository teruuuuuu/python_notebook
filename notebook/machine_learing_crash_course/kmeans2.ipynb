# %%
import math
import numpy as np
import tensorflow as tf
from janome.tokenizer import Tokenizer
from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
from janome.tokenfilter import *

# %%
def wordToDicGen(tokenizer, char_filters, token_filters):
    def wordToDic(text):
        dic = dict()
        for token in Analyzer(char_filters, tokenizer, token_filters).analyze(text):
            dic[token.base_form] = 1
        return dic
    return wordToDic

# %%
def keyWithIndex(dic: dict):
    retdic = dict()
    i = 0
    for key in sorted(dic.keys()):
        retdic[key] = i
        i += 1
    return retdic

# %%
def dicToVec(index_dic, target_dic):
    resultVec = np.zeros(len(index_dic))
    for key in sorted(target_dic):
        if key in index_dic:
            resultVec[index_dic[key]] = 1.0
    return resultVec

# %%
char_filters = [UnicodeNormalizeCharFilter()]
tokenizer = Tokenizer()
token_filters = [CompoundNounFilter(), POSStopFilter(['記号','助詞', '助動詞', '助動詞']), LowerCaseFilter()]
wordToDic = wordToDicGen(tokenizer, char_filters, token_filters)

# %%
def mergeCountDic(someDic, newDic):
    for key in newDic:
        if key in someDic:
            someDic[key] = someDic[key] + 1
        else:
            someDic[key] = 1
    return someDic

# %%
def dicIdfFilter(dic, doc_num):
    resultDic = dict()
    calCache = dict()
    for key in dic:
        if dic[key] not in calCache:
            calCache[dic[key]] = math.log(float(doc_num / dic[key]), math.e)
        if dic[key] >= 2 and calCache[dic[key]] >= 1.5:
            resultDic[key] = calCache[dic[key]] 
    return resultDic

# %%
def textToVec(textList: list, wordToDic):
    someDic = dict()
    textDicList = list()
    for text in textList:
        textDic = wordToDic(text)
        someDic = mergeCountDic(someDic, textDic)
        textDicList.append(textDic)
    indexDic = keyWithIndex(dicIdfFilter(someDic, len(textList)))
    return indexDic, np.vstack((list(map(lambda textDic: dicToVec(indexDic, textDic), textDicList))))

# %%
keizaiNews = list()
for i in range(10):
    keizaiNews.append(open("news/keizai_"  + '{:02}'.format(i+1) + ".txt", "r").read())

# %%
spoNews = list()
for i in range(10):
    spoNews.append(open("news/spo_"  + '{:02}'.format(i+1) + ".txt", "r").read())

# %%
someList = list()
someList.extend(keizaiNews)
someList.extend(spoNews)

# %%
indexDic, textVec = textToVec(someList, wordToDic)

# %%
def input_fn_gen(textVec):
    def input_fn():
        return tf.train.limit_epochs(
            tf.convert_to_tensor(textVec, dtype=tf.float32), num_epochs=30)
    return input_fn

# %%
def train_model(num_clusters, input_fn):
    kmeans = tf.contrib.factorization.KMeansClustering(num_clusters=num_clusters, use_mini_batch=False)
    # train
    num_iterations = 10
    previous_centers = None
    for _ in range(num_iterations):
        kmeans.train(input_fn)
        cluster_centers = kmeans.cluster_centers()
        previous_centers = cluster_centers
    return kmeans, cluster_centers

# %%
def showResult(kmeans, cluster_centers, input_fn, textVec):
    # map the input points to their clusters
    cluster_indices = list(kmeans.predict_cluster_index(input_fn))
    for i, point in enumerate(textVec):
        cluster_index = cluster_indices[i]
        print('index:', i, 'is in cluster', cluster_index)

# %%
entaNews = list()
for i in range(20):
    entaNews.append(open("news/enta_"  + '{:02}'.format(i+1) + ".txt", "r").read())

# %%
keizaiNews = list()
for i in range(20):
    keizaiNews.append(open("news/keizai_"  + '{:02}'.format(i+1) + ".txt", "r").read())

# %%
spoNews = list()
for i in range(20):
    spoNews.append(open("news/spo_"  + '{:02}'.format(i+1) + ".txt", "r").read())

# %%
someList = list()
someList.extend(entaNews)
someList.extend(keizaiNews)
someList.extend(spoNews)

# %%
len(someList)
# Out:
# 60

# %%
indexDic, textVec = textToVec(someList, wordToDic)

# %%
indexDic
# Out:
# {'!': 0,
#  '!」': 1,
#  ')': 2,
#  '-final': 3,
#  '0-0': 4,
#  '1': 5,
#  '10年': 6,
#  '1人': 7,
#  '1次リーグd組': 8,
#  '1試合': 9,
#  '2': 10,
#  '2008年': 11,
#  '2017年': 12,
#  '2018': 13,
#  '2018年9月27日': 14,
#  '22日': 15,
#  '25日': 16,
#  '26日': 17,
#  '27日': 18,
#  '2人': 19,
#  '2戦': 20,
#  '2戦目': 21,
#  '2点': 22,
#  '2節': 23,
#  '2試合': 24,
#  '2連勝': 25,
#  '3': 26,
#  '3戦': 27,
#  '3月': 28,
#  '4': 29,
#  '6月22日': 30,
#  '6月26日': 31,
#  '6月27日': 32,
#  '6月28日': 33,
#  '7月': 34,
#  '7月1日': 35,
#  '<7201>': 36,
#  '<7203>': 37,
#  '?': 38,
#  '?」': 39,
#  'a': 40,
#  'and': 41,
#  'fifaワールドカップ': 42,
#  'game': 43,
#  'goal': 44,
#  'images': 45,
#  'in': 46,
#  'joy-con': 47,
#  'news': 48,
#  'npc': 49,
#  'of': 50,
#  'remix-』': 51,
#  'the': 52,
#  'to': 53,
#  'wonderful': 54,
#  'world': 55,
#  'w杯': 56,
#  'w杯ロシア大会': 57,
#  'w杯出場': 58,
#  'あなた': 59,
#  'あの': 60,
#  'ありがとう': 61,
#  'いい': 62,
#  'いう': 63,
#  'いく': 64,
#  'いける': 65,
#  'いただく': 66,
#  'いっぱい': 67,
#  'いろいろ': 68,
#  'うまい': 69,
#  'うれしい': 70,
#  'お': 71,
#  'おる': 72,
#  'かける': 73,
#  'く': 74,
#  'くださる': 75,
#  'くる': 76,
#  'くれる': 77,
#  'こう': 78,
#  'こうした': 79,
#  'ここ': 80,
#  'こだわる': 81,
#  'こっち': 82,
#  'これ': 83,
#  'これから': 84,
#  'こんな': 85,
#  'ご': 86,
#  'さ': 87,
#  'させる': 88,
#  'さまざま': 89,
#  'さらに': 90,
#  'しかし': 91,
#  'しっかり': 92,
#  'しまう': 93,
#  'しれる': 94,
#  'すぐ': 95,
#  'すでに': 96,
#  'すばらしい': 97,
#  'せく': 98,
#  'せる': 99,
#  'そう': 100,
#  'そこ': 101,
#  'そして': 102,
#  'その': 103,
#  'その他': 104,
#  'その後': 105,
#  'それ': 106,
#  'そんな': 107,
#  'ただ': 108,
#  'ため': 109,
#  'つく': 110,
#  'つながる': 111,
#  'つなぐ': 112,
#  'とき': 113,
#  'ところ': 114,
#  'とどまる': 115,
#  'とる': 116,
#  'どう': 117,
#  'どちら': 118,
#  'どの': 119,
#  'どんどん': 120,
#  'なくす': 121,
#  'はじめ': 122,
#  'はず': 123,
#  'ほか': 124,
#  'ほしい': 125,
#  'ほぼ': 126,
#  'まずは': 127,
#  'また': 128,
#  'まだまだ': 129,
#  'まったく': 130,
#  'みる': 131,
#  'もう': 132,
#  'もちろん': 133,
#  'もの': 134,
#  'もらう': 135,
#  'もらえる': 136,
#  'やすい': 137,
#  'やっぱり': 138,
#  'やはり': 139,
#  'やる': 140,
#  'よい': 141,
#  'より': 142,
#  'よる': 143,
#  'わかる': 144,
#  'わけ': 145,
#  'われわれ': 146,
#  'ん': 147,
#  'アクシデント': 148,
#  'アクション': 149,
#  'アクションゲーム': 150,
#  'アップデート': 151,
#  'アピール': 152,
#  'イタリア': 153,
#  'イベント': 154,
#  'イメージ': 155,
#  'インタビュー': 156,
#  'インターネット': 157,
#  'ウルグアイ': 158,
#  'エニックス': 159,
#  'オランダ': 160,
#  'オーストラリア': 161,
#  'カウンター': 162,
#  'カギ': 163,
#  'カルロス・ゴーン会長': 164,
#  'キャラ': 165,
#  'キャラクター': 166,
#  'クリア': 167,
#  'クロス': 168,
#  'クロース': 169,
#  'グループ': 170,
#  'グループc': 171,
#  'グループh': 172,
#  'グループステージ': 173,
#  'グループリーグ': 174,
#  'グループリーグ突破': 175,
#  'グループ突破': 176,
#  'ゲーム': 177,
#  'ゲーム内': 178,
#  'ゲーム内アイテム': 179,
#  'コメント': 180,
#  'コロンビア': 181,
#  'コンセプト': 182,
#  'ゴール': 183,
#  'サイズ': 184,
#  'サッカー': 185,
#  'サービス': 186,
#  'システム': 187,
#  'シナリオ': 188,
#  'シリーズ': 189,
#  'スクウェア': 190,
#  'スコアレス': 191,
#  'ステージ': 192,
#  'ストーリー': 193,
#  'スピード': 194,
#  'セガゲームス': 195,
#  'セネガル': 196,
#  'セネガル代表': 197,
#  'タイトル': 198,
#  'タッグ': 199,
#  'チャンス': 200,
#  'チーム': 201,
#  'デンマーク': 202,
#  'トヨタ自動車': 203,
#  'トラブル': 204,
#  'ドイツ': 205,
#  'ドラマ': 206,
#  'ナイジェリア': 207,
#  'バトル': 208,
#  'パオロ・ゲレーロ': 209,
#  'ピッチ': 210,
#  'ファン': 211,
#  'フランス': 212,
#  'プレイ': 213,
#  'プレイヤー': 214,
#  'プレゼント': 215,
#  'プレー': 216,
#  'プレーヤー': 217,
#  'ペルー': 218,
#  'ボス': 219,
#  'ボール': 220,
#  'ポジション': 221,
#  'ポドルスキ': 222,
#  'ポーズ': 223,
#  'ポーランド': 224,
#  'マップ': 225,
#  'マーク': 226,
#  'ミクシィ': 227,
#  'メッセージ': 228,
#  'ユーザー': 229,
#  'レベル': 230,
#  'ロシア': 231,
#  'ロシアワールドカップ': 232,
#  'ワールドカップ': 233,
#  'ワールドマップ': 234,
#  '一員': 235,
#  '一度': 236,
#  '一戦': 237,
#  '一方': 238,
#  '一番': 239,
#  '一緒': 240,
#  '上': 241,
#  '上がる': 242,
#  '上回る': 243,
#  '下す': 244,
#  '世界': 245,
#  '世界観': 246,
#  '両': 247,
#  '中': 248,
#  '中心': 249,
#  '主人公': 250,
#  '主張': 251,
#  '予定': 252,
#  '予想': 253,
#  '争う': 254,
#  '事': 255,
#  '交代': 256,
#  '人': 257,
#  '人気': 258,
#  '今': 259,
#  '今回': 260,
#  '今後': 261,
#  '他': 262,
#  '付ける': 263,
#  '付属': 264,
#  '代表': 265,
#  '以下': 266,
#  '以前': 267,
#  '伝える': 268,
#  '伝説': 269,
#  '似る': 270,
#  '位置付ける': 271,
#  '体': 272,
#  '体験': 273,
#  '何': 274,
#  '何度': 275,
#  '作る': 276,
#  '使う': 277,
#  '使用': 278,
#  '使用可能': 279,
#  '価格': 280,
#  '修正': 281,
#  '優しい': 282,
#  '優勝': 283,
#  '元': 284,
#  '先制': 285,
#  '先発': 286,
#  '入る': 287,
#  '入手': 288,
#  '全': 289,
#  '全国': 290,
#  '全面改良': 291,
#  '公開': 292,
#  '具体的': 293,
#  '内容': 294,
#  '再': 295,
#  '写真': 296,
#  '出す': 297,
#  '出る': 298,
#  '出場': 299,
#  '出場機会': 300,
#  '出来る': 301,
#  '分かる': 302,
#  '分ける': 303,
#  '切る': 304,
#  '初': 305,
#  '初めて': 306,
#  '初心者': 307,
#  '初戦': 308,
#  '別': 309,
#  '利用': 310,
#  '制す': 311,
#  '前': 312,
#  '前半': 313,
#  '前日': 314,
#  '劇的fk弾': 315,
#  '力': 316,
#  '加える': 317,
#  '加入': 318,
#  '動き': 319,
#  '動く': 320,
#  '動画': 321,
#  '動画ギャラリー': 322,
#  '務める': 323,
#  '勝ち点': 324,
#  '勝ち点1': 325,
#  '勝ち点3': 326,
#  '勝つ': 327,
#  '勝利': 328,
#  '勝負': 329,
#  '卒業': 330,
#  '参加': 331,
#  '友達': 332,
#  '収録': 333,
#  '取る': 334,
#  '取材': 335,
#  '受ける': 336,
#  '受理': 337,
#  '可能': 338,
#  '可能性': 339,
#  '各': 340,
#  '同': 341,
#  '同じ': 342,
#  '同年': 343,
#  '同日': 344,
#  '同日付': 345,
#  '同時に': 346,
#  '同社': 347,
#  '向ける': 348,
#  '含む': 349,
#  '呼ぶ': 350,
#  '問題': 351,
#  '喜ぶ': 352,
#  '国内外': 353,
#  '基本的': 354,
#  '報道': 355,
#  '報道陣': 356,
#  '報酬': 357,
#  '場合': 358,
#  '場所': 359,
#  '声': 360,
#  '変える': 361,
#  '変わる': 362,
#  '多い': 363,
#  '多く': 364,
#  '多少': 365,
#  '多数追加': 366,
#  '大': 367,
#  '大きい': 368,
#  '大きな': 369,
#  '大会': 370,
#  '失点': 371,
#  '奪う': 372,
#  '奪える': 373,
#  '好き': 374,
#  '始まる': 375,
#  '始める': 376,
#  '姿': 377,
#  '姿勢': 378,
#  '存在': 379,
#  '存在感': 380,
#  '守る': 381,
#  '守備': 382,
#  '実力': 383,
#  '実施': 384,
#  '実際': 385,
#  '対応': 386,
#  '対戦': 387,
#  '対象': 388,
#  '小規模': 389,
#  '少し': 390,
#  '少ない': 391,
#  '届ける': 392,
#  '展開': 393,
#  '崖っぷち': 394,
#  '左': 395,
#  '常に': 396,
#  '幾度': 397,
#  '店舗': 398,
#  '引き分け': 399,
#  '引き分ける': 400,
#  '引き分け以上': 401,
#  '引く': 402,
#  '引退': 403,
#  '強い': 404,
#  '当たる': 405,
#  '当日': 406,
#  '当時': 407,
#  '形': 408,
#  '役割': 409,
#  '彼': 410,
#  '彼ら': 411,
#  '後ろ': 412,
#  '従来': 413,
#  '得る': 414,
#  '得意': 415,
#  '得点': 416,
#  '復帰': 417,
#  '必要': 418,
#  '応じる': 419,
#  '応援': 420,
#  '思い': 421,
#  '思う': 422,
#  '意気込み': 423,
#  '意識': 424,
#  '愛す': 425,
#  '感じる': 426,
#  '感想': 427,
#  '感謝': 428,
#  '懸ける': 429,
#  '成績': 430,
#  '成長': 431,
#  '我々': 432,
#  '戦い': 433,
#  '戦う': 434,
#  '戦略': 435,
#  '手': 436,
#  '手掛ける': 437,
#  '批判': 438,
#  '抑える': 439,
#  '投入': 440,
#  '投手': 441,
#  '折り返す': 442,
#  '抜く': 443,
#  '抽選': 444,
#  '担う': 445,
#  '担当': 446,
#  '持つ': 447,
#  '指名': 448,
#  '指摘': 449,
#  '挑む': 450,
#  '挑戦': 451,
#  '挙げる': 452,
#  '振り返る': 453,
#  '描く': 454,
#  '操作': 455,
#  '改善': 456,
#  '攻撃': 457,
#  '放つ': 458,
#  '故障': 459,
#  '敗れる': 460,
#  '敗退': 461,
#  '教える': 462,
#  '数': 463,
#  '数々': 464,
#  '敵': 465,
#  '新': 466,
#  '新しい': 467,
#  '新た': 468,
#  '方': 469,
#  '方向性': 470,
#  '方法': 471,
#  '日本': 472,
#  '日本代表': 473,
#  '日産自動車': 474,
#  '早い': 475,
#  '明かす': 476,
#  '明らか': 477,
#  '春': 478,
#  '昨年': 479,
#  '暮らし': 480,
#  '最': 481,
#  '最も': 482,
#  '最初': 483,
#  '最大': 484,
#  '最後': 485,
#  '最終節': 486,
#  '最近': 487,
#  '期待': 488,
#  '未': 489,
#  '本': 490,
#  '本作': 491,
#  '本社': 492,
#  '村': 493,
#  '条件': 494,
#  '来る': 495,
#  '東京都内': 496,
#  '果たす': 497,
#  '株主': 498,
#  '株主総会': 499,
#  '楽しい': 500,
#  '楽しむ': 501,
#  '楽しめる': 502,
#  '概要': 503,
#  '様々': 504,
#  '模様': 505,
#  '模索': 506,
#  '機会': 507,
#  '機能': 508,
#  '死': 509,
#  '残す': 510,
#  '比較的': 511,
#  '気': 512,
#  '気づく': 513,
#  '気分': 514,
#  '気持ち': 515,
#  '求める': 516,
#  '決まる': 517,
#  '決める': 518,
#  '決勝トーナメント': 519,
#  '決勝トーナメント進出': 520,
#  '決定': 521,
#  '注意': 522,
#  '注目': 523,
#  '活躍': 524,
#  '消える': 525,
#  '消す': 526,
#  '消化': 527,
#  '深い': 528,
#  '準': 529,
#  '点': 530,
#  '無': 531,
#  '特に': 532,
#  '特定': 533,
#  '特徴': 534,
#  '状態': 535,
#  '状況': 536,
#  '狙う': 537,
#  '獲得': 538,
#  '現在': 539,
#  '現役': 540,
#  '理由': 541,
#  '理解': 542,
#  '生じる': 543,
#  '用意': 544,
#  '申し出': 545,
#  '町': 546,
#  '画像': 547,
#  '異なる': 548,
#  '発売': 549,
#  '発表': 550,
#  '発覚': 551,
#  '登場': 552,
#  '白星': 553,
#  '監督': 554,
#  '目指す': 555,
#  '目標': 556,
#  '目的': 557,
#  '直後': 558,
#  '相手': 559,
#  '短い': 560,
#  '確保': 561,
#  '確定': 562,
#  '確認': 563,
#  '示す': 564,
#  '社会': 565,
#  '私': 566,
#  '積極的': 567,
#  '突破': 568,
#  '立つ': 569,
#  '第': 570,
#  '簡単': 571,
#  '約': 572,
#  '終わる': 573,
#  '終了': 574,
#  '組': 575,
#  '組み合わせ': 576,
#  '組む': 577,
#  '経る': 578,
#  '経験': 579,
#  '結果': 580,
#  '絶対': 581,
#  '絶対条件': 582,
#  '続く': 583,
#  '続ける': 584,
#  '繋ぐ': 585,
#  '繰り広げる': 586,
#  '置く': 587,
#  '美しい': 588,
#  '考え': 589,
#  '考える': 590,
#  '聞く': 591,
#  '背後': 592,
#  '能力': 593,
#  '臨む': 594,
#  '自ら': 595,
#  '自信': 596,
#  '自分': 597,
#  '舞台': 598,
#  '良い': 599,
#  '若い': 600,
#  '融合': 601,
#  '行う': 602,
#  '行く': 603,
#  '行なう': 604,
#  '街': 605,
#  '表明': 606,
#  '製品': 607,
#  '複数': 608,
#  '見える': 609,
#  '見せる': 610,
#  '親しむ': 611,
#  '触れる': 612,
#  '言う': 613,
#  '言葉': 614,
#  '記事': 615,
#  '記念': 616,
#  '記録': 617,
#  '設定': 618,
#  '許す': 619,
#  '試す': 620,
#  '試合': 621,
#  '話': 622,
#  '話す': 623,
#  '詳しい': 624,
#  '詳細': 625,
#  '認める': 626,
#  '認識': 627,
#  '語る': 628,
#  '読む': 629,
#  '課題': 630,
#  '諦める': 631,
#  '豊富': 632,
#  '象徴': 633,
#  '負ける': 634,
#  '貢献': 635,
#  '販売': 636,
#  '責任': 637,
#  '購入': 638,
#  '走る': 639,
#  '起きる': 640,
#  '起こす': 641,
#  '起こる': 642,
#  '超': 643,
#  '迎える': 644,
#  '近い': 645,
#  '近年': 646,
#  '述べる': 647,
#  '追加': 648,
#  '追加点': 649,
#  '送る': 650,
#  '逃す': 651,
#  '通信': 652,
#  '進む': 653,
#  '進める': 654,
#  '進出': 655,
#  '遊ぶ': 656,
#  '過去': 657,
#  '達成': 658,
#  '違う': 659,
#  '選手': 660,
#  '選手たち': 661,
#  '選択': 662,
#  '避ける': 663,
#  '部分': 664,
#  '配信': 665,
#  '重ねる': 666,
#  '重要': 667,
#  '野球': 668,
#  '長い': 669,
#  '開く': 670,
#  '開催': 671,
#  '開始': 672,
#  '開幕': 673,
#  '開発': 674,
#  '間': 675,
#  '集まる': 676,
#  '集める': 677,
#  '難しい': 678,
#  '非常': 679,
#  '韓国': 680,
#  '音楽': 681,
#  '順番': 682,
#  '頑張る': 683,
#  '頭': 684,
#  '飾る': 685,
#  '首位': 686,
#  '驚く': 687,
#  '高い': 688,
#  '高まる': 689,
#  '高める': 690,
#  '高校': 691}

# %%
input_fn = input_fn_gen(textVec)
kmeans, cluster_centers =  train_model(3, input_fn)
showResult(kmeans, cluster_centers, input_fn, textVec)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x132370a90>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 3805.0, step = 1
# INFO:tensorflow:Saving checkpoints for 30 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 31 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 31
# INFO:tensorflow:Saving checkpoints for 61 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-61
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 62 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 62
# INFO:tensorflow:Saving checkpoints for 92 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-92
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 93 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 93
# INFO:tensorflow:Saving checkpoints for 123 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-123
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 124 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 124
# INFO:tensorflow:Saving checkpoints for 154 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-154
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 155 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 155
# INFO:tensorflow:Saving checkpoints for 185 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-185
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 186 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 186
# INFO:tensorflow:Saving checkpoints for 216 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-216
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 217 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 217
# INFO:tensorflow:Saving checkpoints for 247 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-247
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 248 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 248
# INFO:tensorflow:Saving checkpoints for 278 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-278
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 279 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:loss = 1821.054, step = 279
# INFO:tensorflow:Saving checkpoints for 309 into /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1821.054.
# WARNING:tensorflow:Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/jt/w9n_rnhj61xgp3xvr_8mtjvr0000gn/T/tmptn76lsy2/model.ckpt-309
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# index: 0 is in cluster 0
# index: 1 is in cluster 2
# index: 2 is in cluster 0
# index: 3 is in cluster 1
# index: 4 is in cluster 2
# index: 5 is in cluster 0
# index: 6 is in cluster 0
# index: 7 is in cluster 0
# index: 8 is in cluster 0
# index: 9 is in cluster 0
# index: 10 is in cluster 0
# index: 11 is in cluster 0
# index: 12 is in cluster 0
# index: 13 is in cluster 0
# index: 14 is in cluster 0
# index: 15 is in cluster 0
# index: 16 is in cluster 0
# index: 17 is in cluster 2
# index: 18 is in cluster 0
# index: 19 is in cluster 0
# index: 20 is in cluster 2
# index: 21 is in cluster 2
# index: 22 is in cluster 2
# index: 23 is in cluster 2
# index: 24 is in cluster 2
# index: 25 is in cluster 2
# index: 26 is in cluster 2
# index: 27 is in cluster 2
# index: 28 is in cluster 2
# index: 29 is in cluster 2
# index: 30 is in cluster 2
# index: 31 is in cluster 2
# index: 32 is in cluster 2
# index: 33 is in cluster 2
# index: 34 is in cluster 2
# index: 35 is in cluster 2
# index: 36 is in cluster 2
# index: 37 is in cluster 2
# index: 38 is in cluster 2
# index: 39 is in cluster 2
# index: 40 is in cluster 0
# index: 41 is in cluster 1
# index: 42 is in cluster 0
# index: 43 is in cluster 0
# index: 44 is in cluster 1
# index: 45 is in cluster 0
# index: 46 is in cluster 2
# index: 47 is in cluster 1
# index: 48 is in cluster 1
# index: 49 is in cluster 0
# index: 50 is in cluster 2
# index: 51 is in cluster 0
# index: 52 is in cluster 1
# index: 53 is in cluster 2
# index: 54 is in cluster 2
# index: 55 is in cluster 0
# index: 56 is in cluster 2
# index: 57 is in cluster 0
# index: 58 is in cluster 0
# index: 59 is in cluster 0
